# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
from dotenv import load_dotenv
load_dotenv()


from anthropic_client import AnthropicClient
client = AnthropicClient()

# %%
from rag_helper import RAGBase


assistant = RAGBase(index=sqlite_index, llm_client=client)

# %%
print(assistant.rag("can i still join the course?"))
# Out:
# Yes, you can still join the course!
#
# According to the course information, you can join even if you've just discovered it. However, if you want to receive a certificate, there are some important things to know:
#
# 1. **You can join anytime** - There's no restriction on when you can start learning the material in self-paced mode.
#
# 2. **For a certificate**, you need to:
#    - Submit your Capstone project while the live cohort is still accepting submissions
#    - Complete the required peer reviews during the live cohort period
#    - Homework is optional (not required for a certificate)
#
# 3. **Important note**: You can only get a certificate if you complete the course with a "live" cohort. Self-paced learning alone won't qualify you for a certificate.
#
# So go ahead and start - just make sure to submit your Capstone project and do peer reviews while the live cohort is actively accepting them if you want to earn the certificate!

# %%
print("final")
# Out:
# final

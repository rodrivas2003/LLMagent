# %%
from ingest import load_faq_data, build_index

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
from rag_helper import search
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from rag_helper import search
#
# File /workspaces/LLMagent/rag_helper.py:37
#      28     filter_dict = {"course": course}
#      30     return index.search(
#      31         question,
#      32         boost_dict=boost_dict,
#      33         filter_dict=filter_dict,
#      34         num_results=5
#      35     )
# ---> 37 search_results = search(question)
#      39 def build_context(search_results):
#      40     lines = []
#
# NameError: name 'question' is not defined
